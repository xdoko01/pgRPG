# %%
import pyrpg.core.managers.map_manager as map_manager
import pygame
mm = map_manager.MapManager()

# %%
window = pygame.display.set_mode((640,480), 0, 24)

# %%
mm.load_map('test_arena_sand')
mm._maps
# Out:
# {'test_arena_sand': <pyrpg.core.maps.map.Map at 0x6f5bfb8>}

# %%
map = mm.get_map('test_arena_sand')
print(map)

# %%
print(f'{map.height}, {map.width}, {map.name}')
tmxdata = map.tmxdata
# Out:
# 6400, 6400, test_arena_sand

# %%
tmxdata.get_tile_gid(5,5,2)
tmxdata.get_tile_gid(1,1,1)
tmxdata.layers
layer = tmxdata.get_layer_by_name('Tile Layer 1')
print(layer.data[1])
tmxdata.get_tile_gid(1,0,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-87cbb2c398f0> in <module>
# ----> 1 tmxdata.get_tile_gid(5,5,2)
#       2 tmxdata.get_tile_gid(1,1,1)
#       3 tmxdata.layers
#       4 layer = tmxdata.get_layer_by_name('Tile Layer 1')
#       5 print(layer.data[1])
#
# NameError: name 'tmxdata' is not defined
